# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Conv2D

import numpy as np
from glob import glob

IMAGE_SIZE = [224, 224]

train_path = './Train'
valid_path = './Test'

# useful for getting number of output classes
folders = glob('./Train/*')

Classifier=Sequential()

Classifier.add(Conv2D(32,(3,3), input_shape=(224,224,3), activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(64,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

Classifier.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# Use the Image Data Generator to import the images from the dataset
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(
    './Train',
    target_size = (224, 224),
    batch_size = 32,
    class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(
    './Test',
    target_size = (224, 224),
    batch_size = 32,
    class_mode = 'categorical')

# fit the model
r = Classifier.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)

# save the model
Classifier.save('model_Classifier.h5')

# evaluate the model on the test set
scores = Classifier.evaluate(test_set, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Found 153 images belonging to 7 classes.
# Found 42 images belonging to 7 classes.
# C:\Users\Kanis\AppData\Local\Temp\ipykernel_17088\2900839075.py:64: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   r = Classifier.fit_generator(
# Epoch 1/50
# 5/5 [==============================] - 11s 2s/step - loss: 2.3494 - accuracy: 0.1307 - val_loss: 1.8434 - val_accuracy: 0.1429
# Epoch 2/50
# 5/5 [==============================] - 9s 2s/step - loss: 1.7802 - accuracy: 0.2092 - val_loss: 1.5709 - val_accuracy: 0.2857
# Epoch 3/50
# 5/5 [==============================] - 9s 2s/step - loss: 1.6408 - accuracy: 0.2680 - val_loss: 1.7350 - val_accuracy: 0.1667
# Epoch 4/50
# 5/5 [==============================] - 10s 2s/step - loss: 1.6012 - accuracy: 0.2941 - val_loss: 1.3146 - val_accuracy: 0.4762
# Epoch 5/50
# 5/5 [==============================] - 10s 2s/step - loss: 1.4172 - accuracy: 0.3987 - val_loss: 1.3324 - val_accuracy: 0.3571
# Epoch 6/50
# 5/5 [==============================] - 8s 2s/step - loss: 1.3027 - accuracy: 0.5033 - val_loss: 1.2725 - val_accuracy: 0.5476
# Epoch 7/50
# 5/5 [==============================] - 10s 2s/step - loss: 1.1816 - accuracy: 0.5359 - val_loss: 1.1709 - val_accuracy: 0.5000
# Epoch 8/50
# 5/5 [==============================] - 10s 2s/step - loss: 1.0885 - accuracy: 0.5359 - val_loss: 1.0451 - val_accuracy: 0.5238
# Epoch 9/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.9502 - accuracy: 0.6209 - val_loss: 1.1905 - val_accuracy: 0.5476
# Epoch 10/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.8961 - accuracy: 0.6209 - val_loss: 1.0490 - val_accuracy: 0.5476
# Epoch 11/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.8131 - accuracy: 0.7190 - val_loss: 0.9629 - val_accuracy: 0.5238
# Epoch 12/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.7159 - accuracy: 0.7386 - val_loss: 0.7859 - val_accuracy: 0.6190
# Epoch 13/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.6358 - accuracy: 0.7582 - val_loss: 0.8659 - val_accuracy: 0.7381
# Epoch 14/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5923 - accuracy: 0.7712 - val_loss: 0.7938 - val_accuracy: 0.6905
# Epoch 15/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.4811 - accuracy: 0.8497 - val_loss: 0.7932 - val_accuracy: 0.6905
# Epoch 16/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.3647 - accuracy: 0.8889 - val_loss: 1.1570 - val_accuracy: 0.6905
# Epoch 17/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5700 - accuracy: 0.8235 - val_loss: 1.5515 - val_accuracy: 0.5952
# Epoch 18/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.4776 - accuracy: 0.8105 - val_loss: 0.7637 - val_accuracy: 0.7143
# Epoch 19/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.3925 - accuracy: 0.8627 - val_loss: 1.0963 - val_accuracy: 0.6190
# Epoch 20/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.2879 - accuracy: 0.8824 - val_loss: 0.8536 - val_accuracy: 0.6667
# Epoch 21/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.2405 - accuracy: 0.9085 - val_loss: 0.8086 - val_accuracy: 0.7381
# Epoch 22/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.2264 - accuracy: 0.9216 - val_loss: 0.9729 - val_accuracy: 0.7143
# Epoch 23/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.2230 - accuracy: 0.9346 - val_loss: 1.2647 - val_accuracy: 0.6667
# Epoch 24/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.2636 - accuracy: 0.9085 - val_loss: 1.3102 - val_accuracy: 0.6429
# Epoch 25/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.2047 - accuracy: 0.9346 - val_loss: 1.6257 - val_accuracy: 0.5714
# Epoch 26/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.1896 - accuracy: 0.9281 - val_loss: 1.4344 - val_accuracy: 0.5952
# Epoch 27/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1376 - accuracy: 0.9542 - val_loss: 1.3176 - val_accuracy: 0.7143
# Epoch 28/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.2650 - accuracy: 0.8889 - val_loss: 1.2486 - val_accuracy: 0.7143
# Epoch 29/50
# 5/5 [==============================] - 8s 1s/step - loss: 0.1825 - accuracy: 0.9477 - val_loss: 1.2005 - val_accuracy: 0.6905
# Epoch 30/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1376 - accuracy: 0.9673 - val_loss: 1.0686 - val_accuracy: 0.7143
# Epoch 31/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.1413 - accuracy: 0.9608 - val_loss: 1.6506 - val_accuracy: 0.6667
# Epoch 32/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0831 - accuracy: 0.9804 - val_loss: 1.2490 - val_accuracy: 0.7619
# Epoch 33/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0769 - accuracy: 0.9673 - val_loss: 1.3717 - val_accuracy: 0.7143
# Epoch 34/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0860 - accuracy: 0.9739 - val_loss: 0.9045 - val_accuracy: 0.7381
# Epoch 35/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0464 - accuracy: 0.9804 - val_loss: 1.2909 - val_accuracy: 0.7381
# Epoch 36/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0694 - accuracy: 0.9673 - val_loss: 1.2111 - val_accuracy: 0.6905
# Epoch 37/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0699 - accuracy: 0.9804 - val_loss: 1.6331 - val_accuracy: 0.6667
# Epoch 38/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0481 - accuracy: 0.9935 - val_loss: 1.2186 - val_accuracy: 0.7857
# Epoch 39/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0664 - accuracy: 0.9804 - val_loss: 1.0450 - val_accuracy: 0.7619
# Epoch 40/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0428 - accuracy: 0.9935 - val_loss: 1.1310 - val_accuracy: 0.8095
# Epoch 41/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 1.6192 - val_accuracy: 0.7381
# Epoch 42/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0473 - accuracy: 0.9869 - val_loss: 1.1663 - val_accuracy: 0.7857
# Epoch 43/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0303 - accuracy: 0.9935 - val_loss: 1.1872 - val_accuracy: 0.7619
# Epoch 44/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0211 - accuracy: 0.9935 - val_loss: 0.8131 - val_accuracy: 0.8333
# Epoch 45/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0185 - accuracy: 0.9935 - val_loss: 1.1933 - val_accuracy: 0.7857
# Epoch 46/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 1.2934 - val_accuracy: 0.7619
# Epoch 47/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 1.3241 - val_accuracy: 0.7381
# Epoch 48/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.3231 - val_accuracy: 0.7857
# Epoch 49/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.4547 - val_accuracy: 0.7857
# Epoch 50/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0158 - accuracy: 0.9935 - val_loss: 0.9970 - val_accuracy: 0.8095
# C:\Users\Kanis\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Accuracy: 80.95%

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('model_Classifier.h5')

# Load the test image
img = image.load_img('./Test/Tennote/2.jpg', target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

# Preprocess the image and make predictions
img_array = img_array/255.0
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)

# Print the predicted class
print('Predicted Class:', predicted_class)
from gtts import gTTS
import os


# Example text to convert to speech

text = ""
if predicted_class ==0:
    text = "100 rs Note"
elif predicted_class==1:
    text = "200 rs note"
elif predicted_class==2:
    text = "2000 rs note"
elif predicted_class==3:
    text ="500 rs note"
elif predicted_class==4:
    text="50 rs note"
elif predicted_class==5:
    text="10 rs note"
elif predicted_class==6:
    text ="20 rs note"


# Initialize a TTS object with the language (en) and the text to be spoken
tts = gTTS(text=text, lang='en')

# Save the audio file
tts.save("currency_note.mp3")

# Play the audio file

from playsound import playsound

# path to the audio file
audio_file_path = 'currency_note.mp3'

# play the audio file
playsound(audio_file_path)
# Out:
# 1/1 [==============================] - 0s 60ms/step
# Predicted Class: 5
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001F7B2A64250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /_/TranslateWebserverUi/data/batchexecute (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F7B2A64250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\gtts\tts.py:261, in gTTS.stream(self)
#     259 with requests.Session() as s:
#     260     # Send request
# --> 261     r = s.send(
#     262         request=pr, proxies=urllib.request.getproxies(), verify=False
#     263     )
#     265 log.debug("headers-%i: %s", idx, r.request.headers)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /_/TranslateWebserverUi/data/batchexecute (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F7B2A64250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# gTTSError                                 Traceback (most recent call last)
# Cell In[3], line 47
#      44 tts = gTTS(text=text, lang='en')
#      46 # Save the audio file
# ---> 47 tts.save("currency_note.mp3")
#      49 # Play the audio file
#      51 from playsound import playsound
#
# File ~\anaconda3\Lib\site-packages\gtts\tts.py:325, in gTTS.save(self, savefile)
#     315 """Do the TTS API request and write result to file.
#     316
#     317 Args:
#    (...)
#     322
#     323 """
#     324 with open(str(savefile), "wb") as f:
# --> 325     self.write_to_fp(f)
#     326     log.debug("Saved to %s", savefile)
#
# File ~\anaconda3\Lib\site-packages\gtts\tts.py:306, in gTTS.write_to_fp(self, fp)
#     294 """Do the TTS API request(s) and write bytes to a file-like object.
#     295
#     296 Args:
#    (...)
#     302
#     303 """
#     305 try:
# --> 306     for idx, decoded in enumerate(self.stream()):
#     307         fp.write(decoded)
#     308         log.debug("part-%i written to %s", idx, fp)
#
# File ~\anaconda3\Lib\site-packages\gtts\tts.py:277, in gTTS.stream(self)
#     274 except requests.exceptions.RequestException as e:  # pragma: no cover
#     275     # Request failed
#     276     log.debug(str(e))
# --> 277     raise gTTSError(tts=self)
#     279 # Write
#     280 for line in r.iter_lines(chunk_size=1024):
#
# gTTSError: Failed to connect. Probable cause: Unknown
